# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("kc_house_data.csv")
print(data.shape)
# Out:
# (21613, 21)

# %%
x=data['sqft_living'].values
y=data['price'].values

# %%
#plot the data values
plt.scatter(x,y,40,c='y',label='scatter_data',marker='x')
plt.xlabel("sqft_living")
plt.ylabel('price')
plt.title('kc_house price and sqft check')
plt.grid(True,color='k')
plt.show()

# %%
# mean values
mean_x=np.mean(x)
mean_y=np.mean(y)
n=len(x)
mean_x
# Out:
# 2079.8997362698374

# %%
num=0
den=0
for i in range(n):
    num=num+((x[i]-mean_x)*(y[i]-mean_y))
    den=den+((x[i]-mean_x)**2)
m=num/den
c=mean_y-(m*mean_x)
print(m,c)
# Out:
# 280.6235678974486 -43580.743094474776

# %%
y_pred=np.array([])
for i in range(n):
    p=(m*x[i])+c
    y_pred=np.append(y_pred,np.array([p]),axis=0)
print(y_pred)
# Out:
# [287555.06702451 677621.82640197 172499.40418656 ... 242655.29616092
#  405416.96554144 242655.29616092]

# %%
#plot the regression line
plt.plot(x,y_pred,color='m',label="regression_line")
#plot the actual data
plt.scatter(x,y,40,c='g',label="actual_data",marker='o')
plt.scatter(x,y_pred,40,c='k',label="predicted_data",marker='x')
plt.xlabel("sqft_living")
plt.ylabel('price')
plt.legend()
plt.show()

# %%
nu=0
de=0
for i in range(n):
    nu=nu+((y_pred[i]-mean_y)**2) #predicted values of y
    de=de+((y[i]-mean_y)**2) #actual values of y
r2=nu/de
r2
# Out:
# 0.49285321790379133

# %%
x
# Out:
# array([1180, 2570,  770, ..., 1020, 1600, 1020], dtype=int64)

# %%
# predict the profit for city with 45000 and 65000 people
X_test = np.array([[4.5],[6.5]])
y1=(m*X_test[0])+c
y2=(m*X_test[1])+c
print('profit from 45000 people city is ',y1*10000,'$')
print('profit from 65000 people city is ',y2*10000,'$')
# Out:
# profit from 45000 people city is  [-4.2317937e+08] $
# profit from 65000 people city is  [-4.17566899e+08] $

# %%
x=np.array([1.00,2.00,3.00])
y=np.array([1.00,2.50,3.50])
plt.plot(x,y,label='original data',c='r')
plt.legend()

# %%
x_mean=np.mean(x)
y_mean=np.mean(y)
print(x_mean,y_mean)
# Out:
# 2.0 2.3333333333333335
